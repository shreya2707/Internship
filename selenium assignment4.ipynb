# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\shrey\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: trio~=0.17 in c:\users\shrey\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\shrey\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\shrey\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\shrey\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: sniffio in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\shrey\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shrey\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shrey\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\shrey\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\shrey\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get(" https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
# Empty list for scraping data
Rank =[]
Name =[]
Artist =[]
Upload_date=[]
Views=[]

# %%
# Extracting Rank Via X path
try:
    Rank=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
except StaleElementReferenceException:
    Rank.append('NA')

# %%
# Extracting Name Via X path
try:
    Name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name:
        Name.append(i.text)
except NoSuchElementExceptionhElementException:
    Name.append('NA')
except StaleElementReferenceException:
    Name.append('NA')

# %%
# Extracting Artist Name Via Xpath
try:
    Artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementExceptionhElementException:
    Artist.append('NA')
except StaleElementReferenceException:
    Artist.append('NA')

# %%
# Extracting Upload date Via Xpath
try:
    Upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date:
        Upload_date.append(i.text)
except NoSuchElementExceptionhElementException:
    Upload_date.append('NA')
except StaleElementReferenceException:
    Upload_date.append('NA')

# %%
# Extracting Views via Xpath
try:
    Views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views:
        Views.append(i.text)
except NoSuchElementExceptionhElementException:
    Views.append('NA')
except StaleElementReferenceException:
    Views.append('NA')

# %%
print(len(rank),len(name),len(artist),len(upload_date),len(views))
# Out:
# 30 30 30 30 30

# %%
# Dataframe for scrap data
Wiki_YT=pd.DataFrame({'Rank':Rank,'Video Name':Name,'Uploader':Artist,'Views (in Billons)':Views,'Upload Date':Upload_date})
print('\033[1m'+'Most Viewed Video on YouTube from Wikipedia :'+'\033[0m')
Wiki_YT
# Out:
# Most Viewed Video on YouTube from Wikipedia :
#                                                  Rank  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# 16  <selenium.webdriver.remote.webelement.WebEleme...
# 17  <selenium.webdriver.remote.webelement.WebEleme...
# 18  <selenium.webdriver.remote.webelement.WebEleme...
# 19  <selenium.webdriver.remote.webelement.WebEleme...
# 20  <selenium.webdriver.remote.webelement.WebEleme...
# 21  <selenium.webdriver.remote.webelement.WebEleme...
# 22  <selenium.webdriver.remote.webelement.WebEleme...
# 23  <selenium.webdriver.remote.webelement.WebEleme...
# 24  <selenium.webdriver.remote.webelement.WebEleme...
# 25  <selenium.webdriver.remote.webelement.WebEleme...
# 26  <selenium.webdriver.remote.webelement.WebEleme...
# 27  <selenium.webdriver.remote.webelement.WebEleme...
# 28  <selenium.webdriver.remote.webelement.WebEleme...
# 29  <selenium.webdriver.remote.webelement.WebEleme...
# 30                                                 1.
# 31                                                 2.
# 32                                                 3.
# 33                                                 4.
# 34                                                 5.
# 35                                                 6.
# 36                                                 7.
# 37                                                 8.
# 38                                                 9.
# 39                                                10.
# 40                                                11.
# 41                                                12.
# 42                                                13.
# 43                                                14.
# 44                                                15.
# 45                                                16.
# 46                                                17.
# 47                                                18.
# 48                                                19.
# 49                                                20.
# 50                                                21.
# 51                                                22.
# 52                                                23.
# 53                                                24.
# 54                                                25.
# 55                                                26.
# 56                                                27.
# 57                                                28.
# 58                                                29.
# 59                                                30.
#
#                                            Video Name  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# 16  <selenium.webdriver.remote.webelement.WebEleme...
# 17  <selenium.webdriver.remote.webelement.WebEleme...
# 18  <selenium.webdriver.remote.webelement.WebEleme...
# 19  <selenium.webdriver.remote.webelement.WebEleme...
# 20  <selenium.webdriver.remote.webelement.WebEleme...
# 21  <selenium.webdriver.remote.webelement.WebEleme...
# 22  <selenium.webdriver.remote.webelement.WebEleme...
# 23  <selenium.webdriver.remote.webelement.WebEleme...
# 24  <selenium.webdriver.remote.webelement.WebEleme...
# 25  <selenium.webdriver.remote.webelement.WebEleme...
# 26  <selenium.webdriver.remote.webelement.WebEleme...
# 27  <selenium.webdriver.remote.webelement.WebEleme...
# 28  <selenium.webdriver.remote.webelement.WebEleme...
# 29  <selenium.webdriver.remote.webelement.WebEleme...
# 30                              "Baby Shark Dance"[4]
# 31                                     "Despacito"[7]
# 32                         "Johny Johny Yes Papa"[14]
# 33                                    "Bath Song"[15]
# 34                                 "Shape of You"[16]
# 35                                "See You Again"[19]
# 36                  "Phonics Song with Two Words"[24]
# 37                            "Wheels on the Bus"[25]
# 38                                  "Uptown Funk"[26]
# 39    "Learning Colors – Colorful Eggs on a Farm"[27]
# 40                                "Gangnam Style"[28]
# 41     "Masha and the Bear – Recipe for Disaster"[33]
# 42                               "Dame Tu Cosita"[34]
# 43                                       "Axel F"[35]
# 44                                        "Sugar"[36]
# 45                                         "Roar"[37]
# 46                               "Counting Stars"[38]
# 47                                        "Sorry"[39]
# 48                          "Baa Baa Black Sheep"[40]
# 49                            "Thinking Out Loud"[41]
# 50             "Waka Waka (This Time for Africa)"[42]
# 51                                   "Dark Horse"[43]
# 52                               "Lakdi Ki Kathi"[44]
# 53                                        "Faded"[45]
# 54                                      "Perfect"[46]
# 55                                   "Let Her Go"[47]
# 56                               "Girls Like You"[48]
# 57            "Humpty the train on a fruits ride"[49]
# 58                                      "Lean On"[50]
# 59                                     "Bailando"[51]
#
#                                              Uploader  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# 16  <selenium.webdriver.remote.webelement.WebEleme...
# 17  <selenium.webdriver.remote.webelement.WebEleme...
# 18  <selenium.webdriver.remote.webelement.WebEleme...
# 19  <selenium.webdriver.remote.webelement.WebEleme...
# 20  <selenium.webdriver.remote.webelement.WebEleme...
# 21  <selenium.webdriver.remote.webelement.WebEleme...
# 22  <selenium.webdriver.remote.webelement.WebEleme...
# 23  <selenium.webdriver.remote.webelement.WebEleme...
# 24  <selenium.webdriver.remote.webelement.WebEleme...
# 25  <selenium.webdriver.remote.webelement.WebEleme...
# 26  <selenium.webdriver.remote.webelement.WebEleme...
# 27  <selenium.webdriver.remote.webelement.WebEleme...
# 28  <selenium.webdriver.remote.webelement.WebEleme...
# 29  <selenium.webdriver.remote.webelement.WebEleme...
# 30        Pinkfong Baby Shark - Kids' Songs & Stories
# 31                                         Luis Fonsi
# 32                                        LooLoo Kids
# 33                         Cocomelon – Nursery Rhymes
# 34                                         Ed Sheeran
# 35                                        Wiz Khalifa
# 36                                          ChuChu TV
# 37                         Cocomelon – Nursery Rhymes
# 38                                        Mark Ronson
# 39                                        Miroshka TV
# 40                                                Psy
# 41                                         Get Movies
# 42                                          El Chombo
# 43                                         Crazy Frog
# 44                                           Maroon 5
# 45                                         Katy Perry
# 46                                        OneRepublic
# 47                                      Justin Bieber
# 48                         Cocomelon – Nursery Rhymes
# 49                                         Ed Sheeran
# 50                                            Shakira
# 51                                         Katy Perry
# 52                                       Jingle Toons
# 53                                        Alan Walker
# 54                                         Ed Sheeran
# 55                                          Passenger
# 56                                           Maroon 5
# 57      Kiddiestv Hindi – Nursery Rhymes & Kids Songs
# 58                                        Major Lazer
# 59                                   Enrique Iglesias
#
#                                    Views (in Billons)  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# 16  <selenium.webdriver.remote.webelement.WebEleme...
# 17  <selenium.webdriver.remote.webelement.WebEleme...
# 18  <selenium.webdriver.remote.webelement.WebEleme...
# 19  <selenium.webdriver.remote.webelement.WebEleme...
# 20  <selenium.webdriver.remote.webelement.WebEleme...
# 21  <selenium.webdriver.remote.webelement.WebEleme...
# 22  <selenium.webdriver.remote.webelement.WebEleme...
# 23  <selenium.webdriver.remote.webelement.WebEleme...
# 24  <selenium.webdriver.remote.webelement.WebEleme...
# 25  <selenium.webdriver.remote.webelement.WebEleme...
# 26  <selenium.webdriver.remote.webelement.WebEleme...
# 27  <selenium.webdriver.remote.webelement.WebEleme...
# 28  <selenium.webdriver.remote.webelement.WebEleme...
# 29  <selenium.webdriver.remote.webelement.WebEleme...
# 30                                              12.85
# 31                                               8.16
# 32                                               6.70
# 33                                               6.20
# 34                                               6.00
# 35                                               5.89
# 36                                               5.30
# 37                                               5.24
# 38                                               4.92
# 39                                               4.89
# 40                                               4.80
# 41                                               4.55
# 42                                               4.35
# 43                                               3.91
# 44                                               3.87
# 45                                               3.80
# 46                                               3.79
# 47                                               3.66
# 48                                               3.64
# 49                                               3.60
# 50                                               3.59
# 51                                               3.52
# 52                                               3.48
# 53                                               3.45
# 54                                               3.45
# 55                                               3.44
# 56                                               3.42
# 57                                               3.41
# 58                                               3.38
# 59                                               3.38
#
#                                           Upload Date
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# 16  <selenium.webdriver.remote.webelement.WebEleme...
# 17  <selenium.webdriver.remote.webelement.WebEleme...
# 18  <selenium.webdriver.remote.webelement.WebEleme...
# 19  <selenium.webdriver.remote.webelement.WebEleme...
# 20  <selenium.webdriver.remote.webelement.WebEleme...
# 21  <selenium.webdriver.remote.webelement.WebEleme...
# 22  <selenium.webdriver.remote.webelement.WebEleme...
# 23  <selenium.webdriver.remote.webelement.WebEleme...
# 24  <selenium.webdriver.remote.webelement.WebEleme...
# 25  <selenium.webdriver.remote.webelement.WebEleme...
# 26  <selenium.webdriver.remote.webelement.WebEleme...
# 27  <selenium.webdriver.remote.webelement.WebEleme...
# 28  <selenium.webdriver.remote.webelement.WebEleme...
# 29  <selenium.webdriver.remote.webelement.WebEleme...
# 30                                      June 17, 2016
# 31                                   January 12, 2017
# 32                                    October 8, 2016
# 33                                        May 2, 2018
# 34                                   January 30, 2017
# 35                                      April 6, 2015
# 36                                      March 6, 2014
# 37                                       May 24, 2018
# 38                                  November 19, 2014
# 39                                  February 27, 2018
# 40                                      July 15, 2012
# 41                                   January 31, 2012
# 42                                      April 5, 2018
# 43                                      June 16, 2009
# 44                                   January 14, 2015
# 45                                  September 5, 2013
# 46                                       May 31, 2013
# 47                                   October 22, 2015
# 48                                      June 25, 2018
# 49                                    October 7, 2014
# 50                                       June 4, 2010
# 51                                  February 20, 2014
# 52                                      June 14, 2018
# 53                                   December 3, 2015
# 54                                   November 9, 2017
# 55                                      July 25, 2012
# 56                                       May 31, 2018
# 57                                   January 26, 2018
# 58                                     March 22, 2015
# 59                                     April 11, 2014

# %% [markdown]
# 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1stODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get(" https://www.bcci.tv/.")

# %%
# Opening fixtures webpage through browser
fixtures=driver.find_element(By.XPATH,"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14944\1502628976.py in <module>
#       1 # Opening fixtures webpage through browser
# ----> 2 fixtures=driver.find_element(By.XPATH,"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
#       3 try:
#       4     fixtures.click()
#       5 except ElementNotInteractableException:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a"}
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00FA8893+48451]
# 	(No symbol) [0x00F3B8A1]
# 	(No symbol) [0x00E45058]
# 	(No symbol) [0x00E70467]
# 	(No symbol) [0x00E7069B]
# 	(No symbol) [0x00E9DD92]
# 	(No symbol) [0x00E8A304]
# 	(No symbol) [0x00E9C482]
# 	(No symbol) [0x00E8A0B6]
# 	(No symbol) [0x00E67E08]
# 	(No symbol) [0x00E68F2D]
# 	GetHandleVerifier [0x01208E3A+2540266]
# 	GetHandleVerifier [0x01248959+2801161]
# 	GetHandleVerifier [0x0124295C+2776588]
# 	GetHandleVerifier [0x01032280+612144]
# 	(No symbol) [0x00F44F6C]
# 	(No symbol) [0x00F411D8]
# 	(No symbol) [0x00F412BB]
# 	(No symbol) [0x00F34857]
# 	BaseThreadInitThunk [0x76CD7D59+25]
# 	RtlInitializeExceptionChain [0x7769B74B+107]
# 	RtlClearBits [0x7769B6CF+191]

# %% [markdown]
# 3.	Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B)	State
# C)	GSDP(18-19)- at current prices
# D)	GSDP(19-20)- at current prices
# E)	Share(18-19)
# F)	GDP($ billion)

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_13712\3343773433.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')
# Incompatible release of chromedriver (version 113.0.5672.63) detected in PATH: C:\Users\shrey\chromedriver.exe

# %%
# Creating Empty lists
Rank =[]
State =[]
GDSP_19_20=[]
GDSP_18_19 =[]
Share =[]
GDP =[]

# %%
# Clicking on India under ecomony section
India=driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/div/a[3]')
try:
    India.click()
except ElementNotInteractableException:
    driver.get(India.get_attribute('href'))
    
time.sleep(2)

# Clicking Indian State GDP
state = driver.find_element(By.XPATH,'//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]/a')
try:
    state.click()
except ElementNotInteractableException:
    driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Extracting Rank via Xpath
try:
    rank=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
    
# Extracting state name via Xpath
try:
    state=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('NA')
    
# Extracting GDSP 19-20 via Xpath
try:
    gdsp_19_20=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gdsp_19_20:
        GDSP_19_20.append(i.text)
except NoSuchElementException:
    GDSP_19_20.append('NA')
    
# Extracting GDSP 18-19 via Xpath
try:
    gdsp_18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gdsp_18_19:
        GDSP_18_19.append(i.text)
except NoSuchElementException:
    GDSP_18_19.append('NA')
    
# Extracting share in billons via Xpath
try:
     share=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('NA')

# Extracting GDP via Xpath
try:
    gdp=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')
# Out:
#   File "<tokenize>", line 36
#     for i in share:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Dataframe for scrap data
Statewise_GDP=pd.DataFrame({'Rank':Rank,'State':State,'GDSP 19-20':GDSP_19_20,'GDSP 18-19':GDSP_18_19,
                            'Share':Share,'GDP (in Billions)':GDP})
print('\033[1m'+'State-wise GDP of India :'+'\033[0m')
Statewise_GDP
# Out:
# State-wise GDP of India :
# Empty DataFrame
# Columns: [Rank, State, GDSP 19-20, GDSP 18-19, Share, GDP (in Billions)]
# Index: []

# %% [markdown]
# 4.	Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A)	Repository title
# B)	Repository description
# C)	Contributors count
# D)	Language used

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://github.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_13712\1552744873.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')
# Incompatible release of chromedriver (version 113.0.5672.63) detected in PATH: C:\Users\shrey\chromedriver.exe

# %%
# Clicking on trending option
trending=driver.find_element(By.XPATH,'//ul[@class="list-style-none mb-3"][2]/li[3]/a')
try:
    trending.click()
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13712\2267580925.py in <module>
#       1 # Clicking on trending option
# ----> 2 trending=driver.find_element(By.XPATH,'//ul[@class="list-style-none mb-3"][2]/li[3]/a')
#       3 try:
#       4     trending.click()
#       5 except ElementNotInteractableException:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//ul[@class="list-style-none mb-3"][2]/li[3]/a"}
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00F2A813+48355]
# 	(No symbol) [0x00EBC4B1]
# 	(No symbol) [0x00DC5358]
# 	(No symbol) [0x00DF09A5]
# 	(No symbol) [0x00DF0B3B]
# 	(No symbol) [0x00E1E232]
# 	(No symbol) [0x00E0A784]
# 	(No symbol) [0x00E1C922]
# 	(No symbol) [0x00E0A536]
# 	(No symbol) [0x00DE82DC]
# 	(No symbol) [0x00DE93DD]
# 	GetHandleVerifier [0x0118AABD+2539405]
# 	GetHandleVerifier [0x011CA78F+2800735]
# 	GetHandleVerifier [0x011C456C+2775612]
# 	GetHandleVerifier [0x00FB51E0+616112]
# 	(No symbol) [0x00EC5F8C]
# 	(No symbol) [0x00EC2328]
# 	(No symbol) [0x00EC240B]
# 	(No symbol) [0x00EB4FF7]
# 	BaseThreadInitThunk [0x76CD7D59+25]
# 	RtlInitializeExceptionChain [0x7769B74B+107]
# 	RtlClearBits [0x7769B6CF+191]

# %% [markdown]
# 9.	Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants  You have to find the following details:
# A)	Name
# B)	Designation
# C)Company
# D)Skills they hire for
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url=' https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_13712\4264352494.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')
# Incompatible release of chromedriver (version 113.0.5672.63) detected in PATH: C:\Users\shrey\chromedriver.exe
